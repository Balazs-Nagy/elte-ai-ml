# %% [markdown]
# # Exercises 3.
#
# Deadline for submission: 24th of Oct, 2021
#
# These exercises are about operations with files.
# To work on google colab, use the example inside the <b>extras</b> folder, although from now on it is recommended to use Jupyter Notebook or Jupyter Lab on your computer.
#
# A guide for installation:
# https://test-jupyter.readthedocs.io/en/latest/install.html

# %% [markdown]
# ## Merging files
#
# Given text files f1.txt and f2.txt, write a function that reads the files from their path then merges their lines into a new text file f3.txt as follows:
#
# (1) f1_l1\
# (2) f2_l1\
# (3) f1_l2\
# (4) f1_l3\
# (5) f2_l2\
# (6) f2_l3\
# (7) f1_l4\
# (8) f1_l5\
# (9) f1_l6\
# (10) f2_l4\
# (11) f2_l5\
# (12) f2_l6\
# ...
#
# where fi_lj denotes the jth line of fi.txt (i = 1, 2).
#
# ### Example inputs
#
# <b>f1.txt</b>:
#
# aaa\
# bbb\
# ccc\
# ddd\
# eee\
# fff\
# ggg
#
# <b>f2.txt</b>:
#
# zzz\
# yyy\
# xxx\
# www
#
# ### Example output
#
# <b>f3.txt</b>:
#
# aaa\
# zzz\
# bbb\
# ccc\
# yyy\
# xxx\
# ddd\
# eee\
# fff\
# www\
# ggg

# %%
def read_file(path:str) -> str:
    ''' read file from path and return it as a string '''
    with open(path) as file:
        data = file.read()
    return data

# %% [markdown]
# Examples on usage:

# %%
f1 = read_file('files/f1.txt').split('\n')
f1
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd', 'eee', 'fff', 'ggg']

# %%
f2 = read_file('files/f2.txt').split('\n')
f2
# Out:
# ['zzz', 'yyy', 'xxx', 'www']

# %%
def group_list(input_list:list) -> list:
    ''' group list of strings into a growing sequence of lists '''
    mod_list = input_list.copy()
    n = 1
    output_list = []
    while mod_list:
        n = min(len(mod_list),n)
        output_list.append([mod_list.pop(0) for i in range(n)])
        n += 1
    return output_list

# %% [markdown]
# Example on usage:

# %%
group_list(f1)
# Out:
# [['aaa'], ['bbb', 'ccc'], ['ddd', 'eee', 'fff'], ['ggg']]

# %%
group_list(f2)
# Out:
# [['zzz'], ['yyy', 'xxx'], ['www']]

# %%
import itertools
from itertools import zip_longest

def file_merger_function(f1_path, f2_path):
    # 1) read file 2) create list by new lines 3) create list of groups by growing sequence
    f1 = group_list(read_file(f1_path).split('\n'))
    f2 = group_list(read_file(f2_path).split('\n'))
    
    # combine the f1 and f2 (which can be of different length)
    result = [[x for x in t if x is not None] for t in zip_longest(f1, f2)]
    
    # flatten nested lists
    result = list(itertools.chain.from_iterable(result))
    result = list(itertools.chain.from_iterable(result))
    
    # create new lines
    result = '\n'.join(result)
    
    # write to file
    with open('files/f3.txt', 'w') as f3:
        f3.write(result)
    return result

# %%
file_merger_function('files/f1.txt', 'files/f2.txt')
# Out:
# 'aaa\nzzz\nbbb\nccc\nyyy\nxxx\nddd\neee\nfff\nwww\nggg'

# %% [markdown]
# Make a statistics of the word-distribution of 'The Jungle Book' by Rudyard Kipling:
# - The file 'JB.txt' contains the book
# - Use a dictionary, where the individual words are the keys and a word-count are the values.
# - Use only lower case letters (convert upper case letters to lower case) and omit typographical symbols and punctuation marks (like ., :, !, ?, etc) as well.

# %%
with open('files/JB.txt', 'r') as file:
    data = file.read()

# %%
# raw string example
data[:450]
# Out:
# "The Jungle Book\nby\nRudyard Kipling\n\n\nMowgli's Brothers\n\nNow Rann the Kite brings home the night\nThat Mang the Bat sets free--\nThe herds are shut in byre and hut\nFor loosed till dawn are we.\nThis is the hour of pride and power,\nTalon and tush and claw.\nOh, hear the call!--Good hunting all\nThat keep the Jungle Law!\nNight-Song in the Jungle\n\nIt was seven o'clock of a very warm evening in the Seeonee hills\nwhen Father Wolf woke up from his day's rest"

# %%
# printed output example
print(data[:450])
# Out:
# The Jungle Book
# by
# Rudyard Kipling
#
#
# Mowgli's Brothers
#
# Now Rann the Kite brings home the night
# That Mang the Bat sets free--
# The herds are shut in byre and hut
# For loosed till dawn are we.
# This is the hour of pride and power,
# Talon and tush and claw.
# Oh, hear the call!--Good hunting all
# That keep the Jungle Law!
# Night-Song in the Jungle
#
# It was seven o'clock of a very warm evening in the Seeonee hills
# when Father Wolf woke up from his day's rest

# %%
from collections import Counter
from re import sub

def count_unique_words(string:str) -> dict:
    # lower the string
    string = string.lower()
    # remove all special characters (excluding whitespace)
    string = sub('[^A-Za-z0-9\s]+', '', string)
    # split string to words (result is a list)
    words = string.split()
    # count unique words and the number of occureances and map them into a dictionary
    result = dict(zip(Counter(words).keys(), Counter(words).values()))
    return result

# %%
JB_wordcount = count_unique_words(data)
JB_wordcount
# Out:
# {'the': 1141,
#  'jungle': 89,
#  'book': 1,
#  'by': 59,
#  'rudyard': 1,
#  'kipling': 1,
#  'mowglis': 8,
#  'brothers': 6,
#  'now': 46,
#  'rann': 8,
#  'kite': 4,
#  'brings': 1,
#  'home': 4,
#  'night': 22,
#  'that': 223,
#  'mang': 3,
#  'bat': 4,
#  'sets': 3,
#  'free': 16,
#  'herds': 2,
#  'are': 61,
#  'shut': 7,
#  'in': 233,
#  'byre': 2,
#  'and': 693,
#  'hut': 2,
#  'for': 157,
#  'loosed': 1,
#  'till': 22,
#  'dawn': 5,
#  'we': 74,
#  'this': 45,
#  'is': 189,
#  'hour': 3,
#  'of': 388,
#  'pride': 8,
#  'power': 4,
#  'talon': 1,
#  'tush': 1,
#  'claw': 1,
#  'oh': 7,
#  'hear': 7,
#  'callgood': 1,
#  'hunting': 21,
#  'all': 111,
#  'keep': 10,
#  'law': 30,
#  'nightsong': 1,
#  'it': 129,
#  'was': 170,
#  'seven': 1,
#  'oclock': 1,
#  'a': 349,
#  'very': 44,
#  'warm': 7,
#  'evening': 3,
#  'seeonee': 7,
#  'hills': 5,
#  'when': 74,
#  'father': 29,
#  'wolf': 79,
#  'woke': 3,
#  'up': 79,
#  'from': 54,
#  'his': 215,
#  'days': 9,
#  'rest': 2,
#  'scratched': 2,
#  'himself': 21,
#  'yawned': 2,
#  'spread': 1,
#  'out': 44,
#  'paws': 6,
#  'one': 65,
#  'after': 8,
#  'other': 11,
#  'to': 389,
#  'get': 14,
#  'rid': 1,
#  'sleepy': 4,
#  'feeling': 3,
#  'their': 56,
#  'tips': 1,
#  'mother': 27,
#  'lay': 11,
#  'with': 133,
#  'her': 9,
#  'big': 19,
#  'gray': 6,
#  'nose': 3,
#  'dropped': 8,
#  'across': 7,
#  'four': 7,
#  'tumbling': 1,
#  'squealing': 1,
#  'cubs': 20,
#  'moon': 13,
#  'shone': 2,
#  'into': 41,
#  'mouth': 9,
#  'cave': 13,
#  'where': 39,
#  'they': 162,
#  'lived': 10,
#  'augrh': 1,
#  'said': 155,
#  'time': 34,
#  'hunt': 18,
#  'again': 26,
#  'he': 353,
#  'going': 7,
#  'spring': 3,
#  'down': 54,
#  'hill': 9,
#  'little': 61,
#  'shadow': 2,
#  'bushy': 2,
#  'tail': 10,
#  'crossed': 1,
#  'threshold': 1,
#  'whined': 2,
#  'good': 29,
#  'luck': 3,
#  'go': 42,
#  'you': 33,
#  'o': 19,
#  'chief': 1,
#  'wolves': 30,
#  'strong': 7,
#  'white': 8,
#  'teeth': 11,
#  'noble': 4,
#  'children': 8,
#  'may': 26,
#  'never': 41,
#  'forget': 6,
#  'hungry': 12,
#  'world': 3,
#  'jackaltabaqui': 1,
#  'dishlickerand': 1,
#  'india': 2,
#  'despise': 2,
#  'tabaqui': 19,
#  'because': 26,
#  'runs': 3,
#  'about': 11,
#  'making': 6,
#  'mischief': 3,
#  'telling': 3,
#  'tales': 2,
#  'eating': 1,
#  'rags': 1,
#  'pieces': 2,
#  'leather': 1,
#  'village': 5,
#  'rubbishheaps': 1,
#  'but': 108,
#  'afraid': 10,
#  'him': 133,
#  'too': 20,
#  'more': 28,
#  'than': 26,
#  'anyone': 3,
#  'else': 5,
#  'apt': 1,
#  'mad': 2,
#  'then': 62,
#  'forgets': 2,
#  'ever': 16,
#  'through': 25,
#  'forest': 6,
#  'biting': 2,
#  'everything': 4,
#  'way': 12,
#  'even': 15,
#  'tiger': 12,
#  'hides': 1,
#  'goes': 4,
#  'madness': 4,
#  'most': 12,
#  'disgraceful': 1,
#  'thing': 12,
#  'can': 40,
#  'overtake': 1,
#  'wild': 15,
#  'creature': 4,
#  'call': 19,
#  'hydrophobia': 1,
#  'dewaneethe': 1,
#  'run': 20,
#  'enter': 2,
#  'look': 24,
#  'stiffly': 1,
#  'there': 51,
#  'no': 74,
#  'food': 6,
#  'here': 29,
#  'so': 49,
#  'mean': 3,
#  'person': 2,
#  'as': 142,
#  'myself': 4,
#  'dry': 6,
#  'bone': 3,
#  'feast': 1,
#  'who': 44,
#  'gidurlog': 1,
#  'jackal': 3,
#  'people': 36,
#  'pick': 4,
#  'choose': 4,
#  'scuttled': 1,
#  'back': 28,
#  'found': 7,
#  'buck': 9,
#  'some': 21,
#  'meat': 3,
#  'on': 88,
#  'sat': 11,
#  'cracking': 1,
#  'end': 11,
#  'merrily': 1,
#  'thanks': 3,
#  'meal': 2,
#  'licking': 3,
#  'lips': 3,
#  'how': 33,
#  'beautiful': 4,
#  'large': 3,
#  'eyes': 23,
#  'young': 19,
#  'indeed': 8,
#  'i': 225,
#  'might': 8,
#  'have': 99,
#  'remembered': 4,
#  'kings': 5,
#  'men': 26,
#  'beginning': 3,
#  'knew': 17,
#  'well': 23,
#  'nothing': 18,
#  'unlucky': 1,
#  'compliment': 1,
#  'faces': 2,
#  'pleased': 3,
#  'see': 29,
#  'uncomfortable': 1,
#  'still': 18,
#  'rejoicing': 1,
#  'had': 87,
#  'made': 16,
#  'spitefully': 1,
#  'shere': 51,
#  'khan': 43,
#  'has': 46,
#  'shifted': 2,
#  'grounds': 4,
#  'will': 74,
#  'among': 22,
#  'these': 11,
#  'next': 9,
#  'told': 21,
#  'me': 62,
#  'near': 6,
#  'waingunga': 4,
#  'river': 3,
#  'twenty': 6,
#  'miles': 7,
#  'away': 23,
#  'right': 13,
#  'began': 14,
#  'angrilyby': 1,
#  'change': 1,
#  'quarters': 2,
#  'without': 14,
#  'due': 1,
#  'warning': 1,
#  'frighten': 1,
#  'every': 18,
#  'head': 35,
#  'game': 3,
#  'within': 2,
#  'ten': 10,
#  'ii': 4,
#  'kill': 34,
#  'two': 15,
#  'did': 22,
#  'not': 117,
#  'lungri': 2,
#  'lame': 4,
#  'quietly': 7,
#  'been': 25,
#  'foot': 9,
#  'birth': 1,
#  'why': 11,
#  'only': 19,
#  'killed': 16,
#  'cattle': 8,
#  'villagers': 7,
#  'angry': 14,
#  'come': 40,
#  'make': 19,
#  'our': 29,
#  'scour': 1,
#  'far': 10,
#  'must': 32,
#  'grass': 2,
#  'set': 6,
#  'alight': 1,
#  'grateful': 2,
#  'shall': 13,
#  'tell': 11,
#  'your': 12,
#  'gratitude': 1,
#  'snapped': 2,
#  'thy': 29,
#  'master': 11,
#  'thou': 57,
#  'hast': 9,
#  'done': 8,
#  'harm': 5,
#  'enough': 8,
#  'ye': 47,
#  'below': 6,
#  'thickets': 1,
#  'saved': 1,
#  'message': 2,
#  'listened': 2,
#  'valley': 6,
#  'ran': 11,
#  'heard': 23,
#  'snarly': 1,
#  'singsong': 1,
#  'whine': 2,
#  'caught': 7,
#  'does': 7,
#  'care': 6,
#  'if': 41,
#  'knows': 6,
#  'fool': 5,
#  'begin': 2,
#  'nights': 3,
#  'work': 6,
#  'noise': 7,
#  'think': 16,
#  'like': 26,
#  'fat': 5,
#  'bullocks': 1,
#  'hsh': 1,
#  'neither': 4,
#  'bullock': 2,
#  'nor': 6,
#  'hunts': 2,
#  'tonight': 4,
#  'man': 34,
#  'changed': 3,
#  'sort': 2,
#  'humming': 2,
#  'purr': 3,
#  'seemed': 4,
#  'quarter': 1,
#  'compass': 1,
#  'bewilders': 1,
#  'woodcutters': 4,
#  'gypsies': 1,
#  'sleeping': 2,
#  'open': 7,
#  'makes': 2,
#  'them': 53,
#  'sometimes': 5,
#  'showing': 3,
#  'faugh': 2,
#  'beetles': 1,
#  'frogs': 2,
#  'tanks': 4,
#  'eat': 12,
#  'ground': 14,
#  'which': 14,
#  'orders': 3,
#  'anything': 8,
#  'reason': 5,
#  'forbids': 1,
#  'beast': 6,
#  'except': 9,
#  'killing': 4,
#  'show': 7,
#  'outside': 3,
#  'pack': 54,
#  'or': 62,
#  'tribe': 7,
#  'real': 1,
#  'mankilling': 1,
#  'means': 3,
#  'sooner': 3,
#  'later': 6,
#  'arrival': 1,
#  'elephants': 2,
#  'guns': 1,
#  'hundreds': 5,
#  'brown': 10,
#  'gongs': 1,
#  'rockets': 1,
#  'torches': 1,
#  'everybody': 2,
#  'suffers': 1,
#  'beasts': 6,
#  'give': 16,
#  'themselves': 6,
#  'weakest': 1,
#  'defenseless': 1,
#  'living': 2,
#  'things': 22,
#  'unsportsmanlike': 1,
#  'touch': 3,
#  'say': 16,
#  'tooand': 1,
#  'true': 11,
#  'maneaters': 1,
#  'become': 2,
#  'mangy': 1,
#  'lose': 1,
#  'grew': 10,
#  'louder': 1,
#  'ended': 1,
#  'fullthroated': 1,
#  'aaarh': 1,
#  'tigers': 2,
#  'charge': 2,
#  'howlan': 1,
#  'untigerish': 1,
#  'howlfrom': 1,
#  'missed': 6,
#  'what': 59,
#  'few': 5,
#  'paces': 1,
#  'muttering': 1,
#  'mumbling': 1,
#  'savagely': 1,
#  'tumbled': 3,
#  'scrub': 1,
#  'sense': 1,
#  'jump': 4,
#  'at': 84,
#  'campfire': 2,
#  'burned': 3,
#  'feet': 28,
#  'grunt': 2,
#  'something': 12,
#  'coming': 3,
#  'uphill': 1,
#  'twitching': 1,
#  'ear': 1,
#  'ready': 7,
#  'bushes': 2,
#  'rustled': 1,
#  'thicket': 1,
#  'haunches': 3,
#  'under': 19,
#  'leap': 1,
#  'watching': 3,
#  'would': 71,
#  'seen': 9,
#  'wonderful': 7,
#  'worldthe': 1,
#  'checked': 2,
#  'midspring': 1,
#  'bound': 2,
#  'before': 18,
#  'saw': 11,
#  'jumping': 2,
#  'tried': 3,
#  'stop': 3,
#  'result': 1,
#  'shot': 1,
#  'straight': 3,
#  'air': 6,
#  'five': 4,
#  'landing': 2,
#  'almost': 9,
#  'left': 11,
#  'mans': 27,
#  'cub': 39,
#  'directly': 1,
#  'front': 2,
#  'holding': 1,
#  'low': 3,
#  'branch': 13,
#  'stood': 10,
#  'naked': 11,
#  'baby': 2,
#  'could': 46,
#  'just': 9,
#  'walkas': 1,
#  'soft': 4,
#  'dimpled': 1,
#  'atom': 1,
#  'came': 35,
#  'wolfs': 5,
#  'looked': 14,
#  'face': 10,
#  'laughed': 2,
#  'bring': 6,
#  'accustomed': 1,
#  'moving': 1,
#  'own': 25,
#  'necessary': 2,
#  'an': 13,
#  'egg': 1,
#  'breaking': 5,
#  'though': 16,
#  'jaws': 3,
#  'closed': 3,
#  'childs': 1,
#  'tooth': 3,
#  'skin': 7,
#  'laid': 5,
#  'andhow': 1,
#  'bold': 4,
#  'softly': 4,
#  'pushing': 1,
#  'between': 12,
#  'close': 4,
#  'hide': 7,
#  'ahai': 1,
#  'taking': 2,
#  'others': 7,
#  'boast': 2,
#  'such': 8,
#  'my': 64,
#  'altogether': 1,
#  'hair': 4,
#  'looks': 1,
#  'moonlight': 3,
#  'blocked': 2,
#  'khans': 8,
#  'great': 19,
#  'square': 3,
#  'shoulders': 4,
#  'were': 47,
#  'thrust': 4,
#  'entrance': 1,
#  'behind': 11,
#  'squeaking': 1,
#  'lord': 2,
#  'went': 21,
#  'us': 23,
#  'honor': 4,
#  'need': 8,
#  'quarry': 2,
#  'its': 2,
#  'parents': 1,
#  'off': 11,
#  'jumped': 2,
#  'furious': 5,
#  'pain': 1,
#  'narrow': 1,
#  'forepaws': 3,
#  'cramped': 1,
#  'want': 2,
#  'room': 2,
#  'be': 69,
#  'fight': 15,
#  'barrel': 1,
#  'take': 8,
#  'any': 23,
#  'striped': 1,
#  'cattlekiller': 2,
#  'oursto': 1,
#  'do': 52,
#  'talk': 6,
#  'choosing': 1,
#  'bull': 10,
#  'am': 32,
#  'stand': 6,
#  'nosing': 1,
#  'dogs': 9,
#  'den': 1,
#  'fair': 4,
#  'dues': 1,
#  'speak': 15,
#  'roar': 4,
#  'filled': 2,
#  'thunder': 2,
#  'shook': 2,
#  'herself': 2,
#  'clear': 4,
#  'sprang': 2,
#  'forward': 5,
#  'green': 4,
#  'moons': 1,
#  'darkness': 2,
#  'facing': 1,
#  'blazing': 3,
#  'raksha': 1,
#  'demon': 2,
#  'answers': 1,
#  'mine': 4,
#  'lungrimine': 1,
#  'live': 6,
#  'hunter': 5,
#  'cubsfrogeater': 1,
#  'fishkillerhe': 1,
#  'thee': 41,
#  'hence': 2,
#  'sambhur': 6,
#  'starved': 2,
#  'goest': 1,
#  'lamer': 1,
#  'camest': 1,
#  'amazed': 1,
#  'forgotten': 4,
#  'won': 1,
#  'she': 6,
#  'called': 14,
#  'compliments': 1,
#  'sake': 4,
#  'faced': 1,
#  'against': 13,
#  'advantage': 2,
#  'death': 5,
#  'backed': 3,
#  'growling': 2,
#  'shouted': 9,
#  'each': 7,
#  'dog': 2,
#  'barks': 1,
#  'yard': 1,
#  'fostering': 1,
#  'mancubs': 2,
#  'bushtailed': 1,
#  'thieves': 1,
#  'threw': 2,
#  'panting': 2,
#  'gravely': 2,
#  'speaks': 6,
#  'much': 11,
#  'truth': 5,
#  'shown': 1,
#  'wilt': 5,
#  'gasped': 2,
#  'alone': 12,
#  'yet': 7,
#  'pushed': 4,
#  'babes': 1,
#  'side': 5,
#  'already': 2,
#  'butcher': 2,
#  'while': 13,
#  'hunted': 3,
#  'lairs': 9,
#  'revenge': 1,
#  'assuredly': 1,
#  'lie': 3,
#  'frog': 8,
#  'mowgli': 133,
#  'theethe': 1,
#  'lays': 2,
#  'clearly': 1,
#  'marries': 1,
#  'withdraw': 1,
#  'belongs': 1,
#  'soon': 8,
#  'old': 25,
#  'council': 21,
#  'generally': 1,
#  'held': 7,
#  'once': 17,
#  'month': 2,
#  'full': 9,
#  'order': 6,
#  'identify': 1,
#  'inspection': 1,
#  'please': 1,
#  'until': 2,
#  'first': 13,
#  'excuse': 1,
#  'accepted': 4,
#  'grown': 4,
#  'kills': 1,
#  'punishment': 3,
#  'murderer': 1,
#  'minute': 5,
#  'waited': 2,
#  'meeting': 1,
#  'took': 4,
#  'rocka': 1,
#  'hilltop': 1,
#  'covered': 1,
#  'stones': 4,
#  'boulders': 1,
#  'hundred': 9,
#  'akela': 30,
#  'lone': 6,
#  'led': 6,
#  'strength': 7,
#  'cunning': 4,
#  'length': 3,
#  'rock': 14,
#  'forty': 1,
#  'size': 1,
#  'color': 1,
#  'badgercolored': 1,
#  'veterans': 1,
#  'handle': 2,
#  'black': 19,
#  'threeyearolds': 1,
#  'thought': 5,
#  'year': 2,
#  'fallen': 4,
#  'twice': 13,
#  'trap': 5,
#  'youth': 1,
#  'beaten': 1,
#  'dead': 10,
#  'manners': 3,
#  'customs': 3,
#  'talking': 3,
#  'over': 26,
#  'center': 4,
#  'circle': 4,
#  'mothers': 2,
#  'fathers': 1,
#  'senior': 1,
#  'carefully': 2,
#  'return': 2,
#  'place': 11,
#  'noiseless': 1,
#  'push': 2,
#  'sure': 9,
#  'overlooked': 1,
#  'cry': 4,
#  'know': 27,
#  'lawye': 1,
#  'anxious': 2,
#  'looklook': 1,
#  'lastand': 1,
#  'neck': 6,
#  'bristles': 1,
#  'lifted': 3,
#  'camefather': 1,
#  'laughing': 3,
#  'playing': 2,
#  'pebbles': 2,
#  'glistened': 1,
#  'raised': 2,
#  'monotonous': 1,
#  'muffled': 1,
#  'rocksthe': 1,
#  'voice': 9,
#  'crying': 2,
#  'twitched': 1,
#  'ears': 6,
#  'save': 4,
#  'chorus': 1,
#  'deep': 10,
#  'growls': 1,
#  'fourth': 1,
#  'flung': 4,
#  'question': 2,
#  'dispute': 1,
#  'spoken': 5,
#  'least': 7,
#  'members': 1,
#  'answer': 4,
#  'got': 1,
#  'last': 15,
#  'fighting': 5,
#  'allowed': 2,
#  'councilbaloo': 1,
#  'bear': 11,
#  'teaches': 1,
#  'baloo': 93,
#  'pleases': 2,
#  'eats': 1,
#  'nuts': 9,
#  'roots': 1,
#  'honeyrose': 1,
#  'upon': 10,
#  'hind': 1,
#  'grunted': 2,
#  'cubthe': 1,
#  'gift': 1,
#  'words': 17,
#  'let': 16,
#  'entered': 3,
#  'teach': 4,
#  'another': 2,
#  'teacher': 5,
#  'besides': 5,
#  'bagheera': 111,
#  'panther': 17,
#  'inky': 1,
#  'markings': 1,
#  'certain': 2,
#  'lights': 1,
#  'pattern': 1,
#  'watered': 1,
#  'silk': 1,
#  'nobody': 2,
#  'cared': 3,
#  'cross': 2,
#  'path': 3,
#  'buffalo': 1,
#  'reckless': 1,
#  'wounded': 4,
#  'elephant': 4,
#  'honey': 3,
#  'dripping': 2,
#  'tree': 10,
#  'softer': 1,
#  'purred': 1,
#  'assembly': 1,
#  'says': 4,
#  'doubt': 2,
#  'matter': 8,
#  'regard': 1,
#  'new': 9,
#  'life': 11,
#  'bought': 6,
#  'price': 6,
#  'pay': 4,
#  'always': 8,
#  'listen': 6,
#  'knowing': 2,
#  'ask': 4,
#  'leave': 8,
#  'cried': 11,
#  'voices': 3,
#  'shame': 4,
#  'better': 7,
#  'sport': 3,
#  'behalf': 1,
#  'baloos': 4,
#  'word': 11,
#  'add': 1,
#  'newly': 2,
#  'half': 16,
#  'mile': 2,
#  'accept': 1,
#  'according': 3,
#  'difficult': 1,
#  'clamor': 2,
#  'scores': 2,
#  'saying': 3,
#  'die': 10,
#  'winter': 1,
#  'rains': 1,
#  'scorch': 1,
#  'sun': 6,
#  'akelas': 1,
#  'bay': 2,
#  'welllook': 1,
#  'deeply': 2,
#  'interested': 2,
#  'notice': 6,
#  'roared': 3,
#  'handed': 1,
#  'ay': 1,
#  'whiskers': 2,
#  'tune': 1,
#  'wise': 9,
#  'help': 10,
#  'truly': 1,
#  'none': 9,
#  'hope': 3,
#  'lead': 3,
#  'forever': 1,
#  'thinking': 4,
#  'comes': 7,
#  'leader': 10,
#  'gets': 1,
#  'feebler': 3,
#  'upto': 1,
#  'turn': 3,
#  'train': 1,
#  'befits': 1,
#  'content': 2,
#  'skip': 1,
#  'eleven': 1,
#  'whole': 2,
#  'years': 5,
#  'guess': 2,
#  'written': 1,
#  'fill': 2,
#  'many': 10,
#  'books': 1,
#  'course': 3,
#  'child': 5,
#  'taught': 8,
#  'business': 3,
#  'meaning': 3,
#  'rustle': 2,
#  'breath': 7,
#  'note': 1,
#  'owls': 1,
#  'above': 10,
#  'scratch': 2,
#  'bats': 4,
#  'claws': 3,
#  'roosted': 1,
#  'splash': 2,
#  'fish': 2,
#  'pool': 2,
#  'meant': 3,
#  'office': 1,
#  'learning': 2,
#  'slept': 4,
#  'ate': 1,
#  'sleep': 6,
#  'felt': 5,
#  'dirty': 2,
#  'hot': 3,
#  'swam': 2,
#  'pools': 2,
#  'wanted': 3,
#  'pleasant': 3,
#  'raw': 1,
#  'climbed': 3,
#  'showed': 2,
#  'along': 9,
#  'brother': 28,
#  'cling': 1,
#  'sloth': 1,
#  'afterward': 2,
#  'fling': 2,
#  'branches': 20,
#  'boldly': 1,
#  'ape': 3,
#  'met': 4,
#  'discovered': 1,
#  'stared': 4,
#  'hard': 5,
#  'forced': 2,
#  'drop': 4,
#  'used': 5,
#  'stare': 1,
#  'fun': 2,
#  'times': 4,
#  'long': 18,
#  'thorns': 3,
#  'pads': 1,
#  'friends': 9,
#  'suffer': 1,
#  'terribly': 1,
#  'burs': 1,
#  'coats': 1,
#  'hillside': 2,
#  'cultivated': 1,
#  'lands': 3,
#  'curiously': 1,
#  'huts': 4,
#  'mistrust': 1,
#  'box': 1,
#  'gate': 5,
#  'cunningly': 1,
#  'hidden': 2,
#  'nearly': 3,
#  'walked': 5,
#  'loved': 3,
#  'dark': 8,
#  'heart': 8,
#  'drowsy': 1,
#  'day': 17,
#  'mowgliwith': 1,
#  'exception': 1,
#  'understand': 2,
#  'bulls': 1,
#  'thine': 3,
#  'canst': 1,
#  'art': 19,
#  'obeyed': 2,
#  'faithfully': 1,
#  'boy': 13,
#  'grow': 3,
#  'lessons': 1,
#  'trusted': 1,
#  'advice': 1,
#  'forgot': 1,
#  'boythough': 1,
#  'able': 2,
#  'human': 1,
#  'tongue': 5,
#  'crossing': 1,
#  'older': 1,
#  'younger': 1,
#  'followed': 4,
#  'scraps': 1,
#  'dared': 3,
#  'authority': 1,
#  'proper': 2,
#  'bounds': 1,
#  'flatter': 1,
#  'wonder': 1,
#  'fine': 1,
#  'hunters': 1,
#  'dying': 2,
#  'dare': 3,
#  'growl': 1,
#  'bristle': 1,
#  ...}

# %% [markdown]
# ## Invert the dictionary from the previous excercise
#
# Create a new dictionary, where the word-counts are the keys and the values are lists containing the appropriate keys from the previous dictionary.
#
# ## Example:
#
# From d = {
#   'a' : 8,
#   'b' : 3,
#   'c' : 3,
#   'd' : 2,
#   't' : 1,
#   'z' : 1
#   }
#
#   To {
#     1 : ['t', 'z'],
#     2 : ['d'],
#     3 : ['b','c'],
#     8 : ['a']
#   }

# %%
d = { 'a' : 8, 'b' : 3, 'c' : 3, 'd' : 2, 't' : 1, 'z' : 1 }

# %%
def reverse_dict(input_dict:dict) -> dict:
    # empty dict for storing the results
    output_dict = {}
    
    # iterating through all key-value pairs
    for k, v in input_dict.items():
        output_dict[v] = output_dict.get(v, [])
        output_dict[v].append(k)
    # sort results (ascending by key)
    output_dict = dict(sorted(output_dict.items()))
    return output_dict

# %%
reverse_dict(d)
# Out:
# {1: ['t', 'z'], 2: ['d'], 3: ['b', 'c'], 8: ['a']}

# %%
reverse_dict(JB_wordcount)
# Out:
# {1: ['book',
#   'rudyard',
#   'kipling',
#   'brings',
#   'loosed',
#   'talon',
#   'tush',
#   'claw',
#   'callgood',
#   'nightsong',
#   'seven',
#   'oclock',
#   'spread',
#   'rid',
#   'tips',
#   'tumbling',
#   'squealing',
#   'augrh',
#   'crossed',
#   'threshold',
#   'chief',
#   'jackaltabaqui',
#   'dishlickerand',
#   'eating',
#   'rags',
#   'leather',
#   'rubbishheaps',
#   'apt',
#   'hides',
#   'disgraceful',
#   'overtake',
#   'hydrophobia',
#   'dewaneethe',
#   'stiffly',
#   'feast',
#   'gidurlog',
#   'scuttled',
#   'cracking',
#   'merrily',
#   'unlucky',
#   'compliment',
#   'uncomfortable',
#   'rejoicing',
#   'spitefully',
#   'angrilyby',
#   'change',
#   'due',
#   'warning',
#   'frighten',
#   'birth',
#   'scour',
#   'alight',
#   'gratitude',
#   'thickets',
#   'saved',
#   'snarly',
#   'singsong',
#   'bullocks',
#   'hsh',
#   'quarter',
#   'compass',
#   'bewilders',
#   'gypsies',
#   'beetles',
#   'forbids',
#   'real',
#   'mankilling',
#   'arrival',
#   'guns',
#   'gongs',
#   'rockets',
#   'torches',
#   'suffers',
#   'weakest',
#   'defenseless',
#   'unsportsmanlike',
#   'tooand',
#   'maneaters',
#   'mangy',
#   'lose',
#   'louder',
#   'ended',
#   'fullthroated',
#   'aaarh',
#   'howlan',
#   'untigerish',
#   'howlfrom',
#   'paces',
#   'muttering',
#   'mumbling',
#   'savagely',
#   'scrub',
#   'sense',
#   'uphill',
#   'twitching',
#   'ear',
#   'rustled',
#   'thicket',
#   'leap',
#   'worldthe',
#   'midspring',
#   'result',
#   'shot',
#   'directly',
#   'holding',
#   'walkas',
#   'dimpled',
#   'atom',
#   'accustomed',
#   'moving',
#   'egg',
#   'childs',
#   'andhow',
#   'pushing',
#   'ahai',
#   'altogether',
#   'looks',
#   'entrance',
#   'squeaking',
#   'parents',
#   'pain',
#   'narrow',
#   'cramped',
#   'barrel',
#   'striped',
#   'oursto',
#   'choosing',
#   'nosing',
#   'den',
#   'dues',
#   'moons',
#   'facing',
#   'raksha',
#   'answers',
#   'lungrimine',
#   'cubsfrogeater',
#   'fishkillerhe',
#   'goest',
#   'lamer',
#   'camest',
#   'amazed',
#   'won',
#   'compliments',
#   'faced',
#   'barks',
#   'yard',
#   'fostering',
#   'bushtailed',
#   'thieves',
#   'shown',
#   'babes',
#   'revenge',
#   'assuredly',
#   'theethe',
#   'clearly',
#   'marries',
#   'withdraw',
#   'belongs',
#   'generally',
#   'identify',
#   'inspection',
#   'please',
#   'excuse',
#   'kills',
#   'murderer',
#   'meeting',
#   'rocka',
#   'hilltop',
#   'covered',
#   'boulders',
#   'forty',
#   'size',
#   'color',
#   'badgercolored',
#   'veterans',
#   'threeyearolds',
#   'youth',
#   'beaten',
#   'fathers',
#   'senior',
#   'noiseless',
#   'overlooked',
#   'lawye',
#   'looklook',
#   'lastand',
#   'bristles',
#   'camefather',
#   'glistened',
#   'monotonous',
#   'muffled',
#   'rocksthe',
#   'twitched',
#   'chorus',
#   'growls',
#   'fourth',
#   'dispute',
#   'members',
#   'got',
#   'councilbaloo',
#   'teaches',
#   'eats',
#   'roots',
#   'honeyrose',
#   'hind',
#   'cubthe',
#   'gift',
#   'inky',
#   'markings',
#   'lights',
#   'pattern',
#   'watered',
#   'silk',
#   'buffalo',
#   'reckless',
#   'softer',
#   'purred',
#   'assembly',
#   'regard',
#   'behalf',
#   'add',
#   'accept',
#   'difficult',
#   'winter',
#   'rains',
#   'scorch',
#   'akelas',
#   'welllook',
#   'handed',
#   'ay',
#   'tune',
#   'truly',
#   'forever',
#   'gets',
#   'upto',
#   'train',
#   'befits',
#   'skip',
#   'eleven',
#   'written',
#   'books',
#   'note',
#   'owls',
#   'roosted',
#   'office',
#   'ate',
#   'raw',
#   'cling',
#   'sloth',
#   'boldly',
#   'discovered',
#   'stare',
#   'pads',
#   'suffer',
#   'terribly',
#   'burs',
#   'coats',
#   'cultivated',
#   'curiously',
#   'mistrust',
#   'box',
#   'cunningly',
#   'drowsy',
#   'mowgliwith',
#   'exception',
#   'bulls',
#   'canst',
#   'faithfully',
#   'lessons',
#   'trusted',
#   'advice',
#   'forgot',
#   'boythough',
#   'human',
#   'crossing',
#   'older',
#   'younger',
#   'scraps',
#   'authority',
#   'bounds',
#   'flatter',
#   'wonder',
#   'fine',
#   'hunters',
#   'growl',
#   'bristle',
#   'laugh',
#   'lazy',
#   'notion',
#   'count',
#   'loud',
#   'talklike',
#   'rude',
#   'fit',
#   'dig',
#   'pignuts',
#   'palmtree',
#   'foolishness',
#   'mischiefmaker',
#   'concerned',
#   'closely',
#   'ours',
#   'thorn',
#   'jaw',
#   'silky',
#   'giant',
#   'bald',
#   'markthe',
#   'collar',
#   'diedin',
#   'cages',
#   'oodeypore',
#   'bars',
#   'iron',
#   'pan',
#   'bagheerathe',
#   'plaything',
#   'learned',
#   'became',
#   'bagheeraall',
#   'lastto',
#   'brothersif',
#   'whybut',
#   'steadily',
#   'feetbecause',
#   'sullenly',
#   'frowned',
#   'heavy',
#   'eyebrows',
#   'carelessness',
#   'misses',
#   'killand',
#   'costs',
#   'pin',
#   'buckthe',
#   'thenand',
#   'theni',
#   'mens',
#   'mayest',
#   'stronger',
#   'deadly',
#   'invents',
#   'describing',
#   'proudly',
#   'pots',
#   'bagheerahe',
#   'eyesart',
#   'lying',
#   'blacker',
#   'froghunt',
#   'running',
#   'breathing',
#   'troubling',
#   'fields',
#   'bottom',
#   'yell',
#   'bellow',
#   'snort',
#   'bitter',
#   'howls',
#   'sprung',
#   'yelp',
#   'forefoot',
#   'dashed',
#   'fainter',
#   'nestled',
#   'fodder',
#   'tomorrow',
#   'pressed',
#   'hearth',
#   'husbandmans',
#   'wife',
#   'feed',
#   'mists',
#   'wicker',
#   'plastered',
#   'redhot',
#   'charcoal',
#   'blanket',
#   'tend',
#   'cows',
#   'blowing',
#   'woman',
#   'dew',
#   'moonstones',
#   'needed',
#   'firepot',
#   'presently',
#   'blossomed',
#   'nowif',
#   'dreamhow',
#   'beside',
#   'tending',
#   'dipping',
#   'satisfied',
#   'rudely',
#   'sign',
#   'following',
#   'scrapfed',
#   'openly',
#   'flattered',
#   'knees',
#   'speaka',
#   'prime',
#   'seeing',
#   'fawn',
#   'seniors',
#   'thundered',
#   'wearily',
#   'twelve',
#   'trapped',
#   'maimed',
#   'plot',
#   'untried',
#   'weakness',
#   'cleverly',
#   'hush',
#   'single',
#   'bah',
#   'toothless',
#   'doomed',
#   'weary',
#   'manwolf',
#   'troubled',
#   'marrow',
#   'villages',
#   'clamored',
#   'gentlest',
#   'pledge',
#   'lip',
#   'snatch',
#   'doorstep',
#   'offer',
#   'packa',
#   'forgotteni',
#   'bare',
#   'faulta',
#   'gather',
#   'switch',
#   'uprightthe',
#   'wolflike',
#   'hated',
#   'lifes',
#   'sag',
#   'yours',
#   'plainly',
#   'coals',
#   'flared',
#   'undertone',
#   'grim',
#   'mercy',
#   'piteous',
#   'tossing',
#   'quiver',
#   'slowly',
#   'peopleif',
#   'companionship',
#   'merciful',
#   'betray',
#   'betrayed',
#   'flew',
#   'war',
#   'blinking',
#   'stupidly',
#   'ablaze',
#   'flat',
#   'whisker',
#   'gullet',
#   'agony',
#   'pah',
#   'singed',
#   'catgo',
#   'lolling',
#   'somebodies',
#   'outthus',
#   'furiously',
#   'struck',
#   'howling',
#   'sobbed',
#   'henceforward',
#   'farewell',
#   'miserably',
#   'mysterious',
#   'huntingsong',
#   'pond',
#   'sup',
#   'scouting',
#   'beheld',
#   'sought',
#   'bayed',
#   'track',
#   'darkthe',
#   'tonguegive',
#   'spots',
#   'joy',
#   'leopard',
#   'buffalos',
#   'clean',
#   'gloss',
#   'toss',
#   'heavybrowed',
#   'gore',
#   'inform',
#   'oppress',
#   'hail',
#   'sister',
#   'fubsy',
#   'earliest',
#   'maxims',
#   'revenged',
#   'applies',
#   'repeat',
#   'verse',
#   'winds',
#   'sharp',
#   'marks',
#   'lounging',
#   'pet',
#   'getting',
#   'recited',
#   'politely',
#   'hive',
#   'watersnakes',
#   'splashed',
#   'fly',
#   'intruder',
#   'translated',
#   'cuffed',
#   'temper',
#   'spoiled',
#   'ironfeet',
#   'ugh',
#   'ignorance',
#   'earnestly',
#   'protect',
#   'claim',
#   'sharpen',
#   'blunt',
#   'likely',
#   'admired',
#   'steelblue',
#   'rippingchisel',
#   'talons',
#   'itstill',
#   'themif',
#   'bee',
#   'sullen',
#   'slid',
#   'indignant',
#   'adding',
#   'grieved',
#   'knowest',
#   'wolfling',
#   'teachings',
#   'huntingpeople',
#   'thengreat',
#   'scholar',
#   'accent',
#   'whistle',
#   'sentence',
#   'snakepeople',
#   'indescribable',
#   'hiss',
#   'clapped',
#   'applaud',
#   'sideways',
#   'drumming',
#   'heels',
#   'worst',
#   'therethere',
#   'bruise',
#   'begged',
#   'watersnake',
#   'pronounce',
#   'reasonably',
#   'wound',
#   'patting',
#   'furry',
#   'ribs',
#   'dreamer',
#   'dreams',
#   'promised',
#   'ah',
#   'scooped',
#   'bandarlogthe',
#   'jade',
#   'peoplethe',
#   'apesthe',
#   'lawthe',
#   'apes',
#   'snuffled',
#   'snorted',
#   'mountain',
#   'summer',
#   'theythey',
#   'lied',
#   'rumbled',
#   'peoples',
#   'jungleexcept',
#   'outcasts',
#   'overhear',
#   'peep',
#   'leaders',
#   'remembrance',
#   'affairs',
#   'nut',
#   'turns',
#   'laughter',
#   'dealings',
#   'finished',
#   'mouths',
#   'fixed',
#   'filth',
#   'spattered',
#   'coughings',
#   'howlings',
#   'jumpings',
#   'warned',
#   'fresh',
#   'trotted',
#   'belonged',
#   'occasion',
#   'torment',
#   'shriek',
#   'senseless',
#   'invite',
#   'start',
#   'battles',
#   'compromised',
#   'comforted',
#   'reach',
#   'morethe',
#   'invented',
#   'brilliant',
#   'idea',
#   'useful',
#   'inherited',
#   'sorts',
#   'instincts',
#   'considered',
#   'really',
#   'everyone',
#   'nap',
#   'ashamed',
#   'resolving',
#   'legs',
#   'armshard',
#   'handsand',
#   'swash',
#   'triumph',
#   'scuffled',
#   'upper',
#   'admire',
#   'treeland',
#   'describe',
#   'crossroads',
#   'seventy',
#   'travel',
#   'gone',
#   'giddy',
#   'enjoying',
#   'glimpses',
#   'check',
#   'swing',
#   'thinnest',
#   'topmost',
#   'crackle',
#   'bend',
#   'whoop',
#   'outward',
#   'lower',
#   'limbs',
#   'mast',
#   'sea',
#   'lash',
#   'guards',
#   'bounding',
#   'crashing',
#   'yelling',
#   'swept',
#   'prisoner',
#   'struggle',
#   'send',
#   'useless',
#   'topsides',
#   'upward',
#   'blue',
#   'balancing',
#   'wheeling',
#   'yards',
#   'whether',
#   'load',
#   'whistled',
#   'surprise',
#   'treetop',
#   'forwe',
#   'waves',
#   'chil',
#   'balanced',
#   'speck',
#   'telescope',
#   'pecking',
#   'eyesight',
#   'pecked',
#   'fledgling',
#   'rocked',
#   'meantime',
#   'grief',
#   'poor',
#   'clumsy',
#   'trot',
#   'overtaking',
#   'slaying',
#   'wewe',
#   'catch',
#   'tire',
#   'cow',
#   'lawcubbeatera',
#   'burst',
#   'plan',
#   'arrula',
#   'whoo',
#   'trust',
#   'hives',
#   'stung',
#   'bury',
#   'miserable',
#   'bears',
#   'arulala',
#   'wahooa',
#   'clasped',
#   'rolled',
#   'moaning',
#   'correctly',
#   'impatiently',
#   'respect',
#   'thinks',
#   'idleness',
#   'licked',
#   'forepaw',
#   'thoughtfully',
#   'rootdigging',
#   'uncoiling',
#   'steals',
#   'footlessand',
#   'hopefully',
#   'sleeps',
#   'asleep',
#   'awake',
#   'suspicious',
#   'rubbed',
#   'faded',
#   'ledge',
#   'admiring',
#   'retirement',
#   'changing',
#   'splendiddarting',
#   'bluntnosed',
#   'twisting',
#   'fantastic',
#   'knots',
#   'curves',
#   'dinner',
#   'beautifully',
#   'mottled',
#   'jacket',
#   'careful',
#   'blind',
#   'snakein',
#   'fact',
#   'despised',
#   'cowardsbut',
#   'lapped',
#   'anybody',
#   'sitting',
#   'breed',
#   'deaf',
#   'accident',
#   'lowered',
#   'oho',
#   'needs',
#   'afoot',
#   'carelessly',
#   'permission',
#   'woodpath',
#   'mere',
#   'chance',
#   'psshaw',
#   'maybe',
#   'lengtha',
#   'newgrown',
#   'timber',
#   'huntvery',
#   'indeedand',
#   'slipping',
#   'tight',
#   'wrapped',
#   'names',
#   'footless',
#   'earthworm',
#   'sssss',
#   'anythingeven',
#   'kid',
#   'bandarlogbecause',
#   'hegoats',
#   'sweetly',
#   'especially',
#   'wary',
#   'shows',
#   'swallowing',
#   'either',
#   'ripple',
#   'bulge',
#   'itit',
#   'stuck',
#   'owned',
#   'doings',
#   'takes',
#   'huntersleaders',
#   'certainon',
#   'replied',
#   'courteously',
#   'swelled',
#   'curiosity',
#   'wolfcubs',
#   'humble',
#   'nutstealers',
#   'pickers',
#   'quills',
#   'presumptuous',
#   'boldest',
#   'mancubsmy',
#   'famous',
#   'jungles',
#   'iwelove',
#   'praise',
#   'properly',
#   'vainvain',
#   'envied',
#   'alsoyellow',
#   'wormwormearthworm',
#   'remind',
#   'aaassp',
#   'wandering',
#   'whither',
#   'sunset',
#   'wouldst',
#   'frogsor',
#   'scum',
#   'waterhole',
#   'hillo',
#   'sweeping',
#   'upturned',
#   'flanges',
#   'ranns',
#   'bedtime',
#   'ranged',
#   'foliage',
#   'cityto',
#   'gorge',
#   'circled',
#   'roost',
#   'remembering',
#   'firmly',
#   'proud',
#   'deserted',
#   'buried',
#   'boar',
#   'tribes',
#   'anywhere',
#   'selfrespecting',
#   'animal',
#   'eyeshot',
#   'drought',
#   'halfruined',
#   'journeyat',
#   'anxiously',
#   'quickfootkaa',
#   'abreast',
#   'shortly',
#   'effort',
#   'panthercanter',
#   'strive',
#   'rockpython',
#   'gained',
#   'clearing',
#   'slow',
#   'goer',
#   'speckled',
#   'wormearthworm',
#   'boot',
#   'pour',
#   'finding',
#   'shortest',
#   'heap',
#   'ruins',
#   'king',
#   'trace',
#   'causeways',
#   'gates',
#   'splinters',
#   'worn',
#   'rusted',
#   'hinges',
#   'decayed',
#   'windows',
#   'towers',
#   'clumps',
#   'crowned',
#   'courtyards',
#   'fountains',
#   'split',
#   'stained',
#   'cobblestones',
#   'courtyard',
#   'apart',
#   'grasses',
#   'honeycombs',
#   'blackness',
#   'shapeless',
#   'block',
#   'idol',
#   'pits',
#   'dimples',
#   'corners',
#   'public',
#   'wells',
#   'shattered',
#   'domes',
#   'temples',
#   'figs',
#   'sprouting',
#   'pretended',
#   'buildings',
#   'hall',
#   'chamber',
#   'fleas',
#   'collect',
#   'plaster',
#   'bricks',
#   'terraces',
#   'garden',
#   'shake',
#   'oranges',
#   'flowers',
#   'explored',
#   'passages',
#   'tunnels',
#   'rooms',
#   'drifted',
#   'ones',
#   'twos',
#   'drank',
#   'muddy',
#   'mobs',
#   'clever',
#   'hoping',
#   'trained',
#   'late',
#   'journey',
#   'joined',
#   'danced',
#   'sang',
#   'companions',
#   'capture',
#   'marked',
#   'history',
#   'canes',
#   'imitate',
#   'minutes',
#   'interest',
#   'fours',
#   'coughing',
#   'pawpaws',
#   'roamed',
#   'leadersnothing',
#   'picking',
#   'thievish',
#   'happy',
#   'pinching',
#   'sandstone',
#   'halffull',
#   'domed',
#   'roof',
#   'underground',
#   'passage',
#   'screens',
#   'tracerybeautiful',
#   'milkwhite',
#   'fretwork',
#   'agates',
#   'cornelians',
#   'jasper',
#   'lapis',
#   'lazuli',
#   'casting',
#   'velvet',
#   'embroidery',
#   'listener',
#   'future',
#   'selves',
#   ...],
#  2: ['herds',
#   'byre',
#   'hut',
#   'rest',
#   'scratched',
#   'yawned',
#   'shone',
#   'shadow',
#   'bushy',
#   'whined',
#   'india',
#   'despise',
#   'tales',
#   'pieces',
#   'mad',
#   'forgets',
#   'biting',
#   'enter',
#   'person',
#   'meal',
#   'faces',
#   'shifted',
#   'quarters',
#   'within',
#   'lungri',
#   'grass',
#   'grateful',
#   'snapped',
#   'message',
#   'listened',
#   'whine',
#   'begin',
#   'bullock',
#   'hunts',
#   'sort',
#   'humming',
#   'sleeping',
#   'makes',
#   'faugh',
#   'frogs',
#   'elephants',
#   'everybody',
#   'living',
#   'become',
#   'tigers',
#   'charge',
#   'campfire',
#   'grunt',
#   'bushes',
#   'checked',
#   'bound',
#   'jumping',
#   'landing',
#   'front',
#   'baby',
#   'laughed',
#   'necessary',
#   'taking',
#   'boast',
#   'blocked',
#   'lord',
#   'quarry',
#   'its',
#   'jumped',
#   'want',
#   'room',
#   'cattlekiller',
#   'filled',
#   'thunder',
#   'shook',
#   'herself',
#   'sprang',
#   'darkness',
#   'demon',
#   'hence',
#   'starved',
#   'advantage',
#   'growling',
#   'dog',
#   'mancubs',
#   'threw',
#   'panting',
#   'gravely',
#   'gasped',
#   'already',
#   'butcher',
#   'lays',
#   'month',
#   'until',
#   'waited',
#   'handle',
#   'year',
#   'mothers',
#   'carefully',
#   'return',
#   'push',
#   'anxious',
#   'playing',
#   'pebbles',
#   'raised',
#   'crying',
#   'question',
#   'allowed',
#   'pleases',
#   'grunted',
#   'another',
#   'certain',
#   'nobody',
#   'cross',
#   'dripping',
#   'doubt',
#   'knowing',
#   'newly',
#   'mile',
#   'clamor',
#   'scores',
#   'bay',
#   'deeply',
#   'interested',
#   'whiskers',
#   'content',
#   'whole',
#   'guess',
#   'fill',
#   'rustle',
#   'scratch',
#   'splash',
#   'fish',
#   'pool',
#   'learning',
#   'dirty',
#   'swam',
#   'pools',
#   'showed',
#   'afterward',
#   'fling',
#   'forced',
#   'fun',
#   'hillside',
#   'hidden',
#   'understand',
#   'obeyed',
#   'able',
#   'proper',
#   'dying',
#   'everywhere',
#   'porcupine',
#   'often',
#   'enemy',
#   'palm',
#   'naturally',
#   'mao',
#   'peacock',
#   'deer',
#   'wast',
#   'feel',
#   'muscles',
#   'hid',
#   'glossy',
#   'spot',
#   'fed',
#   'silly',
#   'ways',
#   'terrible',
#   'tenderly',
#   'returned',
#   'shifting',
#   'meet',
#   'friend',
#   'swiftly',
#   'arm',
#   'doing',
#   'freed',
#   'tale',
#   'mist',
#   'chatter',
#   'plunged',
#   'downward',
#   'wicked',
#   'knocked',
#   'croplands',
#   'spoke',
#   'window',
#   'both',
#   'lumps',
#   'morning',
#   'strode',
#   'corner',
#   'disappeared',
#   'bark',
#   'stuff',
#   'halfway',
#   'shining',
#   'frightened',
#   'jackals',
#   'kept',
#   'folly',
#   'snarled',
#   'bared',
#   'eaters',
#   'cowards',
#   'mana',
#   'sorrow',
#   'jabber',
#   'lit',
#   'tuft',
#   'moss',
#   'terror',
#   'flames',
#   'crackled',
#   'whirled',
#   'cowering',
#   'shadows',
#   'staring',
#   'kicked',
#   'sparks',
#   'debt',
#   'case',
#   'accidents',
#   'thus',
#   'ram',
#   'whimpered',
#   'longer',
#   'tongues',
#   'drive',
#   'burning',
#   'part',
#   'belled',
#   'stole',
#   'waiting',
#   'hark',
#   'kaas',
#   'horns',
#   'stranger',
#   'happened',
#   'serious',
#   'delighted',
#   'pupil',
#   'hyaena',
#   'deal',
#   'lesson',
#   'swim',
#   'laws',
#   'sound',
#   'bees',
#   'disturbed',
#   'midday',
#   'strangers',
#   'repeated',
#   'pleasure',
#   'same',
#   'softness',
#   'beating',
#   'ringing',
#   'reached',
#   'kites',
#   'perfectly',
#   'aside',
#   'bird',
#   'feared',
#   'stomach',
#   'trying',
#   'pulling',
#   'kicking',
#   'dirt',
#   'whoof',
#   'pity',
#   'stillness',
#   'cool',
#   'carried',
#   'bade',
#   'speech',
#   'stolen',
#   'falling',
#   'minds',
#   'whisper',
#   'shameless',
#   'desire',
#   'hardly',
#   'shower',
#   'high',
#   'thin',
#   'sick',
#   'howl',
#   'songs',
#   'memories',
#   'weave',
#   'wind',
#   'envy',
#   'boughs',
#   'skill',
#   'flight',
#   'regular',
#   'roads',
#   'strongest',
#   'fast',
#   'boys',
#   'jerk',
#   'escort',
#   'cough',
#   'hanging',
#   'whooping',
#   'treeroads',
#   'pace',
#   'carrying',
#   'shrieked',
#   'nodded',
#   'bigger',
#   'wings',
#   'beneath',
#   'didst',
#   'speed',
#   'chasing',
#   'memory',
#   'curled',
#   'unless',
#   'afternoon',
#   'relief',
#   'hug',
#   'huge',
#   'coils',
#   'less',
#   'fault',
#   'beyond',
#   'stories',
#   'badly',
#   'ts',
#   'weaving',
#   'chattering',
#   'toward',
#   'illo',
#   'thick',
#   'hurried',
#   'level',
#   'distance',
#   'steady',
#   'keeping',
#   'indian',
#   'built',
#   'creepers',
#   'rows',
#   'street',
#   'scuffling',
#   'crowds',
#   'fruit',
#   'shout',
#   'gentle',
#   'rain',
#   'picked',
#   'pull',
#   'try',
#   'queens',
#   'excellent',
#   'bitten',
#   'ditch',
#   'slope',
#   'glided',
#   'wondered',
#   'six',
#   'dome',
#   'hissing',
#   'second',
#   'cobras',
#   'worked',
#   'inch',
#   'slip',
#   'coiled',
#   'scattered',
#   'bands',
#   'imagine',
#   'sent',
#   'hurrying',
#   'stayed',
#   'shaking',
#   'screenwork',
#   'hissed',
#   'pythons',
#   'trembling',
#   'dance',
#   'hunger',
#   'figures',
#   'darker',
#   'nearer',
#   'account',
#   'dont',
#   'butnever',
#   'plain',
#   'cut',
#   'pointed',
#   'priest'],
#  3: ['mang',
#   'sets',
#   'hour',
#   'evening',
#   'woke',
#   'feeling',
#   'nose',
#   'spring',
#   'luck',
#   'world',
#   'runs',
#   'mischief',
#   'telling',
#   'anyone',
#   'mean',
#   'bone',
#   'jackal',
#   'meat',
#   'thanks',
#   'licking',
#   'lips',
#   'large',
#   'beginning',
#   'pleased',
#   'river',
#   'game',
#   'nights',
#   'changed',
#   'purr',
#   'showing',
#   'orders',
#   'outside',
#   'means',
#   'sooner',
#   'touch',
#   'tumbled',
#   'burned',
#   'coming',
#   'haunches',
#   'watching',
#   'tried',
#   'stop',
#   'straight',
#   'low',
#   'jaws',
#   'closed',
#   'tooth',
#   'moonlight',
#   'square',
#   'forepaws',
#   'blazing',
#   'backed',
#   'hunted',
#   'lie',
#   'punishment',
#   'length',
#   'manners',
#   'customs',
#   'talking',
#   'lifted',
#   'laughing',
#   'entered',
#   'cared',
#   'path',
#   'honey',
#   'voices',
#   'sport',
#   'according',
#   'saying',
#   'roared',
#   'hope',
#   'lead',
#   'feebler',
#   'turn',
#   'course',
#   'business',
#   'meaning',
#   'claws',
#   'meant',
#   'hot',
#   'wanted',
#   'pleasant',
#   'climbed',
#   'ape',
#   'thorns',
#   'lands',
#   'nearly',
#   'loved',
#   'thine',
#   'grow',
#   'dared',
#   'dare',
#   'strike',
#   'swung',
#   'whose',
#   'surely',
#   'chin',
#   'rolling',
#   'paid',
#   'lock',
#   'hate',
#   'lives',
#   'grows',
#   'slipped',
#   'splendid',
#   'son',
#   'plowed',
#   'stream',
#   'yells',
#   'panted',
#   'inside',
#   'earth',
#   'dried',
#   'gathered',
#   'whispered',
#   'asked',
#   'silence',
#   'seasons',
#   'known',
#   'therefore',
#   'bones',
#   'yelled',
#   'eaten',
#   'driven',
#   'teaching',
#   'promise',
#   'arms',
#   'beat',
#   'stir',
#   'instead',
#   'tears',
#   'doe',
#   'wood',
#   'find',
#   'quick',
#   'rotten',
#   'fifty',
#   'aloud',
#   'whenever',
#   'hit',
#   'dost',
#   'today',
#   'trunk',
#   'heads',
#   'thank',
#   'giving',
#   'safe',
#   'dancing',
#   'top',
#   'kind',
#   'bad',
#   'monkeyfolk',
#   'pretend',
#   'drink',
#   'forbidden',
#   'seldom',
#   'sticks',
#   'wisest',
#   'swaying',
#   'cries',
#   'rush',
#   'dragged',
#   'dust',
#   'hung',
#   'chuckle',
#   'blows',
#   'roll',
#   'tails',
#   'rather',
#   'thirty',
#   'poison',
#   'news',
#   'hurry',
#   'throat',
#   'manthing',
#   'best',
#   'stay',
#   'reservoirs',
#   'battlements',
#   'roofless',
#   'fought',
#   'stopped',
#   'west',
#   'alive',
#   'rubbish',
#   'dozen',
#   'battle',
#   'opened',
#   'owe',
#   'lines',
#   'hangs'],
#  4: ['kite',
#   'home',
#   'bat',
#   'power',
#   'sleepy',
#   'noble',
#   'everything',
#   'goes',
#   'madness',
#   'creature',
#   'myself',
#   'pick',
#   'choose',
#   'beautiful',
#   'remembered',
#   'grounds',
#   'waingunga',
#   'ii',
#   'lame',
#   'neither',
#   'tonight',
#   'seemed',
#   'woodcutters',
#   'tanks',
#   'killing',
#   'jump',
#   'five',
#   'soft',
#   'bold',
#   'softly',
#   'close',
#   'hair',
#   'shoulders',
#   'thrust',
#   'honor',
#   'fair',
#   'roar',
#   'clear',
#   'green',
#   'mine',
#   'forgotten',
#   'sake',
#   'pushed',
#   'accepted',
#   'grown',
#   'took',
#   'stones',
#   'cunning',
#   'fallen',
#   'center',
#   'circle',
#   'cry',
#   'save',
#   'flung',
#   'answer',
#   'teach',
#   'wounded',
#   'elephant',
#   'says',
#   'pay',
#   'ask',
#   'shame',
#   'baloos',
#   'thinking',
#   'bats',
#   'slept',
#   'met',
#   'stared',
#   'drop',
#   'times',
#   'huts',
#   'followed',
#   'blow',
#   'ikki',
#   'ho',
#   'believe',
#   'pulled',
#   'stretched',
#   'yes',
#   'broke',
#   'paw',
#   'leaves',
#   'love',
#   'leaping',
#   'name',
#   'twilight',
#   'around',
#   'bounded',
#   'drew',
#   'snap',
#   'watched',
#   'twigs',
#   'looking',
#   'leadership',
#   'worth',
#   'three',
#   'rage',
#   'fur',
#   'taken',
#   'fall',
#   'break',
#   'trail',
#   'leaped',
#   'small',
#   'learn',
#   'warn',
#   'bruised',
#   'protection',
#   'hathi',
#   'shoulder',
#   'shouting',
#   'weight',
#   'watch',
#   'trouble',
#   'goats',
#   'haste',
#   'waked',
#   'lost',
#   'road',
#   'marble',
#   'houses',
#   'sides',
#   'circles',
#   'fell',
#   'summerhouse'],
#  5: ['dawn',
#   'hills',
#   'village',
#   'else',
#   'kings',
#   'harm',
#   'fool',
#   'fat',
#   'sometimes',
#   'reason',
#   'hundreds',
#   'few',
#   'wolfs',
#   'breaking',
#   'laid',
#   'furious',
#   'forward',
#   'hunter',
#   'death',
#   'truth',
#   'wilt',
#   'side',
#   'minute',
#   'thought',
#   'trap',
#   'spoken',
#   'fighting',
#   'teacher',
#   'besides',
#   'years',
#   'child',
#   'felt',
#   'hard',
#   'used',
#   'gate',
#   'walked',
#   'tongue',
#   'perhaps',
#   'mark',
#   'palace',
#   'broken',
#   'rose',
#   'howled',
#   'coat',
#   'also',
#   'fro',
#   'light',
#   'tired',
#   'birds',
#   'throw',
#   'evil',
#   'noticed',
#   'monkeypeople',
#   'mind',
#   'python',
#   'body',
#   'yellow',
#   'snakes',
#   'stone',
#   'ruined'],
#  6: ['brothers',
#   'paws',
#   'gray',
#   'forget',
#   'making',
#   'forest',
#   'food',
#   'dry',
#   'near',
#   'twenty',
#   'set',
#   'below',
#   'valley',
#   'care',
#   'knows',
#   'work',
#   'nor',
#   'beast',
#   'later',
#   'beasts',
#   'themselves',
#   'missed',
#   'air',
#   'bring',
#   'talk',
#   'stand',
#   'live',
#   'sambhur',
#   'she',
#   'speaks',
#   'order',
#   'lone',
#   'led',
#   'neck',
#   'ears',
#   'bought',
#   'price',
#   'listen',
#   'sun',
#   'notice',
#   'sleep',
#   'born',
#   'ago',
#   'those',
#   'cannot',
#   'brought',
#   'carry',
#   'hold',
#   'quickly',
#   'wait',
#   'whom',
#   'sit',
#   'climb',
#   'answered',
#   'treetops',
#   'empty',
#   'sore',
#   'cloud',
#   'tank',
#   'manling'],
#  7: ['shut',
#   'oh',
#   'hear',
#   'warm',
#   'seeonee',
#   'across',
#   'four',
#   'going',
#   'strong',
#   'found',
#   'miles',
#   'quietly',
#   'villagers',
#   'caught',
#   'does',
#   'noise',
#   'open',
#   'show',
#   'tribe',
#   'ready',
#   'wonderful',
#   'skin',
#   'hide',
#   'others',
#   'each',
#   'yet',
#   'held',
#   'strength',
#   'least',
#   'better',
#   'comes',
#   'breath',
#   'hand',
#   'turned',
#   'pot',
#   'gave',
#   'hurt',
#   'follow',
#   'snake'],
#  8: ['mowglis',
#   'rann',
#   'pride',
#   'after',
#   'dropped',
#   'white',
#   'children',
#   'indeed',
#   'might',
#   'cattle',
#   'done',
#   'enough',
#   'anything',
#   'such',
#   'khans',
#   'need',
#   'take',
#   'frog',
#   'soon',
#   'matter',
#   'always',
#   'leave',
#   'taught',
#   'dark',
#   'heart',
#   'put',
#   'wish',
#   'flower',
#   'blood',
#   'use',
#   'play',
#   'water',
#   'wall'],
#  9: ['days',
#   'her',
#   'mouth',
#   'hill',
#   'buck',
#   'next',
#   'foot',
#   'hast',
#   'except',
#   'seen',
#   'almost',
#   'just',
#   'dogs',
#   'shouted',
#   'lairs',
#   'full',
#   'hundred',
#   'sure',
#   'voice',
#   'nuts',
#   'new',
#   'wise',
#   'none',
#   'along',
#   'friends',
#   'foolish',
#   'walls',
#   'terrace'],
#  10: ['keep',
#   'lived',
#   'tail',
#   'afraid',
#   'ten',
#   'far',
#   'brown',
#   'grew',
#   'stood',
#   'face',
#   'bull',
#   'dead',
#   'deep',
#   'upon',
#   'tree',
#   'die',
#   'help',
#   'leader',
#   'many',
#   'above',
#   'fire',
#   'together',
#   'monkey'],
#  11: ['other',
#   'lay',
#   'teeth',
#   'about',
#   'sat',
#   'end',
#   'these',
#   'why',
#   'tell',
#   'master',
#   'ran',
#   'true',
#   'saw',
#   'left',
#   'naked',
#   'behind',
#   'off',
#   'much',
#   'place',
#   'bear',
#   'life',
#   'cried',
#   'word',
#   'bagheeras',
#   'cold',
#   'trees',
#   'city'],
#  12: ['hungry',
#   'way',
#   'tiger',
#   'most',
#   'thing',
#   'your',
#   'eat',
#   'something',
#   'between',
#   'alone',
#   'should',
#   'remember',
#   'round',
#   'hands'],
#  13: ['moon',
#   'cave',
#   'right',
#   'shall',
#   'branch',
#   'an',
#   'against',
#   'while',
#   'first',
#   'twice',
#   'boy',
#   'fear',
#   'junglepeople'],
#  14: ['get',
#   'began',
#   'without',
#   'angry',
#   'ground',
#   'which',
#   'looked',
#   'called',
#   'rock',
#   'red',
#   'being'],
#  15: ['even', 'wild', 'two', 'fight', 'speak', 'last'],
#  16: ['free',
#   'ever',
#   'made',
#   'killed',
#   'think',
#   'give',
#   'say',
#   'though',
#   'let',
#   'half'],
#  17: ['knew', 'once', 'words', 'panther', 'day'],
#  18: ['hunt', 'nothing', 'still', 'every', 'before', 'long'],
#  19: ['big',
#   'o',
#   'tabaqui',
#   'call',
#   'young',
#   'only',
#   'make',
#   'under',
#   'great',
#   'black',
#   'art',
#   'mancub'],
#  20: ['cubs', 'too', 'run', 'branches'],
#  21: ['hunting', 'himself', 'some', 'told', 'went', 'council'],
#  22: ['night', 'till', 'among', 'did', 'things'],
#  23: ['eyes', 'well', 'away', 'heard', 'us', 'any'],
#  24: ['look'],
#  25: ['through', 'been', 'own', 'old'],
#  26: ['again', 'may', 'because', 'than', 'men', 'like', 'over'],
#  27: ['mother', 'mans', 'know'],
#  28: ['more', 'back', 'feet', 'brother', 'bandarlog'],
#  29: ['father', 'good', 'here', 'see', 'our', 'thy'],
#  30: ['law', 'wolves', 'akela'],
#  32: ['must', 'am'],
#  33: ['you', 'how'],
#  34: ['time', 'kill', 'man'],
#  35: ['head', 'came'],
#  36: ['people'],
#  39: ['where', 'cub'],
#  40: ['can', 'come', 'monkeys'],
#  41: ['into', 'never', 'if', 'thee'],
#  42: ['go'],
#  43: ['khan'],
#  44: ['very', 'out', 'who'],
#  45: ['this'],
#  46: ['now', 'has', 'could'],
#  47: ['ye', 'were'],
#  49: ['so'],
#  51: ['there', 'shere'],
#  52: ['do'],
#  53: ['them'],
#  54: ['from', 'down', 'pack'],
#  55: ['kaa'],
#  56: ['their'],
#  57: ['thou'],
#  59: ['by', 'what'],
#  61: ['are', 'little'],
#  62: ['then', 'me', 'or'],
#  64: ['my'],
#  65: ['one'],
#  69: ['be'],
#  71: ['would'],
#  74: ['we', 'when', 'no', 'will'],
#  79: ['wolf', 'up'],
#  84: ['at'],
#  87: ['had'],
#  88: ['on'],
#  89: ['jungle'],
#  93: ['baloo'],
#  99: ['have'],
#  108: ['but'],
#  111: ['all', 'bagheera'],
#  117: ['not'],
#  129: ['it'],
#  133: ['with', 'him', 'mowgli'],
#  142: ['as'],
#  155: ['said'],
#  157: ['for'],
#  162: ['they'],
#  170: ['was'],
#  189: ['is'],
#  215: ['his'],
#  223: ['that'],
#  225: ['i'],
#  233: ['in'],
#  349: ['a'],
#  353: ['he'],
#  388: ['of'],
#  389: ['to'],
#  693: ['and'],
#  1141: ['the']}
